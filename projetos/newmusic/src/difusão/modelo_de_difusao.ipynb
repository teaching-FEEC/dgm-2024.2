# %%
# !apt-get install fluidsynth -y  # Instala o FluidSynth no sistema
# !pip install pyfluidsynth pretty_midi numpy torch torchaudio
# !pip install audio-diffusion-pytorch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Agora você pode acessar seus arquivos em '/content/drive/My Drive'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import pretty_midi
import subprocess
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader

class NpyToWavDataset(Dataset):
    def __init__(self, npy_directory, output_directory, soundfont_path, fluidsynth_path, sample_rate=22050, duration=12):
        self.file_paths = [os.path.join(npy_directory, f) for f in os.listdir(npy_directory) if f.endswith('.npy')]
        self.output_directory = output_directory
        self.soundfont_path = soundfont_path
        self.fluidsynth_path = fluidsynth_path
        self.sample_rate = sample_rate
        self.num_samples = sample_rate * duration

        # Cria o diretório de saída, se necessário
        os.makedirs(output_directory, exist_ok=True)

    def piano_roll_to_midi(self, piano_roll, midi_file):
        pm = pretty_midi.PrettyMIDI(initial_tempo=120, resolution=480)  # Define tempo e resolução
        instrument = pretty_midi.Instrument(program=0)  # Piano

        for pitch, roll in enumerate(piano_roll):
            notes = np.where(roll > 0)[0]
            for note in notes:
                start = note / 16  # Ajuste o número de passos por segundo conforme necessário
                end = (note + 1) / 16
                midi_note = pretty_midi.Note(velocity=100, pitch=pitch + 21, start=start, end=end)
                instrument.notes.append(midi_note)

        pm.instruments.append(instrument)
        pm.write(midi_file)

    def midi_to_wav(self, midi_file, wav_file):
        subprocess.run(
            [
                self.fluidsynth_path,
                "-ni",
                self.soundfont_path,
                midi_file,
                "-F", wav_file,
                "-r", str(self.sample_rate)
            ],
            check=True
        )

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
      npy_file = self.file_paths[idx]
      piano_roll = np.load(npy_file)

      # Arquivos de saída
      midi_file = os.path.join(self.output_directory, f"{os.path.basename(npy_file).replace('.npy', '.mid')}")
      wav_file = os.path.join(self.output_directory, f"{os.path.basename(npy_file).replace('.npy', '.wav')}")

      # Converte piano roll para MIDI e MIDI para WAV
      self.piano_roll_to_midi(piano_roll, midi_file)
      self.midi_to_wav(midi_file, wav_file)

      # Carregar áudio como tensor
      waveform, _ = torchaudio.load(wav_file)

      # Converter para mono se necessário
      if waveform.size(0) == 2:  # Áudio estéreo
          waveform = waveform.mean(dim=0, keepdim=True)  # Converte para mono

      # Ajustar o tamanho do waveform
      if waveform.size(1) > self.num_samples:
          waveform = waveform[:, :self.num_samples]  # Trunca se maior
      elif waveform.size(1) < self.num_samples:
          padding = self.num_samples - waveform.size(1)  # Calcula o padding
          waveform = torch.nn.functional.pad(waveform, (0, padding), mode='constant', value=0)  # Preenche com zeros

      # Adicionar canal extra
      waveform = waveform.unsqueeze(0)  # (1, 1, num_samples)

      # Debug para validar a forma do tensor
      #print(f"Tamanho do waveform final: {waveform.shape}")

      return waveform

# %%
from torch.utils.data import random_split

# Configurações
npy_directory = "/content/drive/MyDrive/diffusion/JCP_mixed"
output_directory = "/content/drive/MyDrive/diffusion/data_output"
soundfont_path = "/content/drive/MyDrive/diffusion/GeneralUser_GS_v2.0.1--doc_r3/GeneralUser-GS/GeneralUser-GS.sf2"
fluidsynth_path = "/usr/bin/fluidsynth"

# Cria o Dataset e DataLoader
dataset = NpyToWavDataset(npy_directory, output_directory, soundfont_path, fluidsynth_path)

# Tamanho total do dataset
dataset_size = len(dataset)

# Proporção de treino e validação
train_ratio = 0.1
val_ratio = 0.01

# Cálculo dos tamanhos
train_size = int(dataset_size * train_ratio)
val_size = int(dataset_size * val_ratio)
diff = dataset_size - train_size - val_size

# Divisão aleatória
train_dataset, val_dataset, diff_ = random_split(dataset, [train_size, val_size, diff])

# Criação dos DataLoaders
batch_size = 4
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=8)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=8)

print(f"Tamanho do conjunto de treino: {len(train_dataset)}")
print(f"Tamanho do conjunto de validação: {len(val_dataset)}")

# Itera pelo DataLoader
#for batch in train_dataloader:
#    print(batch.shape)  # Cada batch será um tensor com waveforms
# Out:
# Tamanho do conjunto de treino: 357
# Tamanho do conjunto de validação: 35

# %%
import torch
from audio_diffusion_pytorch import DiffusionModel, UNetV0, VDiffusion, VSampler

# Configuração do modelo
#model = DiffusionModel(
#    net_t=UNetV0,
#    in_channels=1,  # Áudio mono
#    channels=[8, 32, 64, 128, 256, 512, 512, 1024, 1024],
#    factors=[1, 4, 4, 4, 2, 2, 2, 2, 2],
#    items=[1, 2, 2, 2, 2, 2, 2, 4, 4],
#    attentions=[0, 0, 0, 0, 0, 1, 1, 1, 1],
#    attention_heads=8,
#    attention_features=64,
#    diffusion_t=VDiffusion,
#    sampler_t=VSampler,
#)  # Mova o modelo para a GPU, se disponível

# Arquitetura mais simples
model = DiffusionModel(
    net_t=UNetV0,
    in_channels=1,
    channels=[8, 16],  # Reduzindo para duas camadas
    factors=[1, 2],
    items=[1, 1],
    attentions=[0, 1],
    attention_heads=2,
    attention_features=8,
    diffusion_t=VDiffusion,
    sampler_t=VSampler,
)

#from torch import nn

#for name, module in model.named_modules():
#    if isinstance(module, nn.GroupNorm):
#        print(f"Ajustando GroupNorm no módulo: {name}")
#        num_channels = module.num_channels
#        new_layer = nn.LayerNorm([num_channels])  # Substitui por LayerNorm
#        setattr(module, name.split('.')[-1], new_layer)


# Otimizador
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
#def align_tensors_hook(module, input, output):
#    # Ajusta o tamanho da dimensão temporal (dimensão 2)
#    if isinstance(output, torch.Tensor) and output.dim() == 3:
#        min_length = min(t.size(2) for t in input if isinstance(t, torch.Tensor) and t.dim() == 3)
#        if output.size(2) > min_length:
#            return output[:, :, :min_length]  # Trunca para o menor tamanho
#        elif output.size(2) < min_length:
#            padding = min_length - output.size(2)
#            return torch.nn.functional.pad(output, (0, padding))  # Adiciona padding
#    return output
#
## Registra o hook
#for name, module in model.named_modules():
#    if isinstance(module, nn.Conv1d):  # Foco em camadas convolucionais
#        module.register_forward_hook(align_tensors_hook)
#

# %%
import torch
import os
import pandas as pd
import torch_xla.core.xla_model as xm

# Configurações
save_path = "/content/drive/MyDrive/diffusion/saved_models"  # Diretório para salvar os modelos no Google Drive
os.makedirs(save_path, exist_ok=True)

# Verificar GPU/TPU
device = xm.xla_device()  # Dispositivo XLA (TPU)
print(f"Usando dispositivo: {device}")

# Mover modelo para o dispositivo
model = model.to(device)

# Configurações para salvar os dados
train_losses = []  # Lista para armazenar as perdas do treinamento
val_losses = []    # Lista para armazenar as perdas da validação

# Função para calcular a perda no conjunto de validação
def validate(model, val_dataloader):
    model.eval()  # Coloca o modelo em modo de validação
    val_loss = 0.0
    with torch.no_grad():  # Desativa o cálculo de gradiente para validação
        for batch in val_dataloader:
            batch = batch.to(device)
            #print(f"Entrada do modelo val - Shape: {batch.shape}, Tipo: {type(batch)}, Device: {batch.device}")

            # Ajustar a forma do batch
            if batch.dim() == 4 and batch.size(2) == 1:
              batch = batch.squeeze(2)  # Remove a dimensão extra

            if batch.size(-1) != 16000:
              if batch.size(-1) > 16000:
                batch = batch[..., :16000]
              else:
                padding = 16000 - batch.size(-1)
                batch = torch.nn.functional.pad(batch, (0, padding))

            loss = model(batch)
            val_loss += loss.item()
    return val_loss / len(val_dataloader)  # Média das perdas

# Loop de treinamento
num_epochs = 30  # Defina o número de épocas conforme necessário
for epoch in range(num_epochs):
    #torch.cuda.empty_cache()
    model.train()  # Coloca o modelo em modo de treinamento
    epoch_train_loss = 0.0

    # Loop de treinamento
    total_batches = len(train_dataloader)
    for batch_idx, batch in enumerate(train_dataloader, start=1):
        batch = batch.to(device)
        #print(f"Entrada do modelo train - Shape: {batch.shape}, Tipo: {type(batch)}, Device: {batch.device}")

      # Ajustar a forma do batch
        if batch.dim() == 4 and batch.size(2) == 1:
          batch = batch.squeeze(2)  # Remove a dimensão extra

        if batch.size(-1) != 16000:
          if batch.size(-1) > 16000:
            batch = batch[..., :16000]
          else:
            padding = 16000 - batch.size(-1)
            batch = torch.nn.functional.pad(batch, (0, padding))


        print(f"[Época {epoch + 1}/{num_epochs}] Batch {batch_idx}/{total_batches} - Forma do batch ajustado: {batch.shape}")

        try:
            optimizer.zero_grad()
            loss = model(batch)  # Calcula a perda
            loss.backward()
            xm.optimizer_step(optimizer)  # Atualização de gradientes na TPU
            epoch_train_loss += loss.item()

            # Imprime a perda do batch
            print(f"  [Batch {batch_idx}] Loss: {loss.item():.4f} - Restam {total_batches - batch_idx} batches na época")

            # Salvar o modelo após cada época
            model_save_path = f"{save_path}/model_epoch_{epoch + 1}_{batch_idx}.pt"
            torch.save(model.state_dict(), model_save_path)
            #output = model(batch)
            #if output.dim() == 0:
              #print(f"Saída escalar no batch {batch_idx}. Output: {output.shape}")
              #print('--')
        except RuntimeError as e:
          print(f"Erro durante o treinamento no batch {batch_idx}: {e}")
          continue  # Ignora o batch problemático e continua

    # Cálculo da perda média no treinamento
    epoch_train_loss /= total_batches
    train_losses.append(epoch_train_loss)

    # Cálculo da perda no conjunto de validação
    epoch_val_loss = validate(model, val_dataloader)
    val_losses.append(epoch_val_loss)

    # Salvar o modelo após cada época
    model_save_path = f"{save_path}/model_epoch_{epoch + 1}.pt"
    torch.save(model.state_dict(), model_save_path)
    print(f"Modelo salvo em {model_save_path}")

    # Exibir resultados da época
    print(f"Época {epoch + 1}/{num_epochs}, Loss Treino: {epoch_train_loss:.4f}, Loss Validação: {epoch_val_loss:.4f}")

# Salvar as perdas em um arquivo
losses_df = pd.DataFrame({"Train Loss": train_losses, "Validation Loss": val_losses})
losses_df.to_csv(f"{save_path}/losses.csv", index=False)
print(f"Treinamento concluído. Dados de perda salvos em {save_path}/losses.csv.")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_xla/__init__.py:253: UserWarning: `tensorflow` can conflict with `torch-xla`. Prefer `tensorflow-cpu` when using PyTorch/XLA. To silence this warning, `pip uninstall -y tensorflow && pip install tensorflow-cpu`. If you are in a notebook environment such as Colab or Kaggle, restart your notebook runtime afterwards.
#   warnings.warn(
# Usando dispositivo: xla:0
# [Época 1/30] Batch 1/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 1] Loss: 0.3686 - Restam 89 batches na época
# [Época 1/30] Batch 2/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 2] Loss: 0.0342 - Restam 88 batches na época
# [Época 1/30] Batch 3/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 3] Loss: 0.3876 - Restam 87 batches na época
# [Época 1/30] Batch 4/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 4] Loss: 0.3142 - Restam 86 batches na época
# [Época 1/30] Batch 5/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 5] Loss: 0.4025 - Restam 85 batches na época
# [Época 1/30] Batch 6/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 6] Loss: 0.3852 - Restam 84 batches na época
# [Época 1/30] Batch 7/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 7] Loss: 0.1882 - Restam 83 batches na época
# [Época 1/30] Batch 8/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 8] Loss: 0.3005 - Restam 82 batches na época
# [Época 1/30] Batch 9/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 9] Loss: 0.2851 - Restam 81 batches na época
# [Época 1/30] Batch 10/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 10] Loss: 0.2798 - Restam 80 batches na época
# [Época 1/30] Batch 11/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 11] Loss: 0.3990 - Restam 79 batches na época
# [Época 1/30] Batch 12/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 12] Loss: 0.2070 - Restam 78 batches na época
# [Época 1/30] Batch 13/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 13] Loss: 0.4425 - Restam 77 batches na época
# [Época 1/30] Batch 14/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 14] Loss: 0.4895 - Restam 76 batches na época
# [Época 1/30] Batch 15/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 15] Loss: 0.0608 - Restam 75 batches na época
# [Época 1/30] Batch 16/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 16] Loss: 0.3595 - Restam 74 batches na época
# [Época 1/30] Batch 17/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 17] Loss: 0.2130 - Restam 73 batches na época
# [Época 1/30] Batch 18/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 18] Loss: 0.4403 - Restam 72 batches na época
# [Época 1/30] Batch 19/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 19] Loss: 0.2702 - Restam 71 batches na época
# [Época 1/30] Batch 20/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 20] Loss: 0.3838 - Restam 70 batches na época
# [Época 1/30] Batch 21/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 21] Loss: 0.4574 - Restam 69 batches na época
# [Época 1/30] Batch 22/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 22] Loss: 0.1921 - Restam 68 batches na época
# [Época 1/30] Batch 23/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 23] Loss: 0.3533 - Restam 67 batches na época
# [Época 1/30] Batch 24/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 24] Loss: 0.1422 - Restam 66 batches na época
# [Época 1/30] Batch 25/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 25] Loss: 0.2308 - Restam 65 batches na época
# [Época 1/30] Batch 26/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch
90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 63] Loss: 0.4983 - Restam 27 batches na época
# [Época 1/30] Batch 64/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 64] Loss: 0.3085 - Restam 26 batches na época
# [Época 1/30] Batch 65/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 65] Loss: 0.1832 - Restam 25 batches na época
# [Época 1/30] Batch 66/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 66] Loss: 0.4084 - Restam 24 batches na época
# [Época 1/30] Batch 67/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 67] Loss: 0.1370 - Restam 23 batches na época
# [Época 1/30] Batch 68/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 68] Loss: 0.4186 - Restam 22 batches na época
# [Época 1/30] Batch 69/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 69] Loss: 0.3347 - Restam 21 batches na época
# [Época 1/30] Batch 70/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 70] Loss: 0.0616 - Restam 20 batches na época
# [Época 1/30] Batch 71/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 71] Loss: 0.2161 - Restam 19 batches na época
# [Época 1/30] Batch 72/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 72] Loss: 0.0665 - Restam 18 batches na época
# [Época 1/30] Batch 73/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 73] Loss: 0.2196 - Restam 17 batches na época
# [Época 1/30] Batch 74/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 74] Loss: 0.1725 - Restam 16 batches na época
# [Época 1/30] Batch 75/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 75] Loss: 0.1337 - Restam 15 batches na época
# [Época 1/30] Batch 76/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 76] Loss: 0.2016 - Restam 14 batches na época
# [Época 1/30] Batch 77/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 77] Loss: 0.4249 - Restam 13 batches na época
# [Época 1/30] Batch 78/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 78] Loss: 0.4705 - Restam 12 batches na época
# [Época 1/30] Batch 79/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 79] Loss: 0.6046 - Restam 11 batches na época
# [Época 1/30] Batch 80/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 80] Loss: 0.3706 - Restam 10 batches na época
# [Época 1/30] Batch 81/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 81] Loss: 0.3230 - Restam 9 batches na época
# [Época 1/30] Batch 82/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 82] Loss: 0.4673 - Restam 8 batches na época
# [Época 1/30] Batch 83/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 83] Loss: 0.4779 - Restam 7 batches na época
# [Época 1/30] Batch 84/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 84] Loss: 0.7841 - Restam 6 batches na época
# [Época 1/30] Batch 85/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 85] Loss: 0.4457 - Restam 5 batches na época
# [Época 1/30] Batch 86/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 86] Loss: 0.2815 - Restam 4 batches na época
# [Época 1/30] Batch 87/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 87] Loss: 0.6344 - Restam 3 batches na época
# [Época 1/30] Batch 88/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 88] Loss: 0.3256 - Restam 2 batches na época
# [Época 1/30] Batch 89/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 89] Loss: 0.6709 - Restam 1 batches na época
# [Época 1/30] Batch 90/90 - Forma do batch ajustado: torch.Size([1, 1, 16000])
#   [Batch 90] Loss: 0.0484 - Restam 0 batches na época
# Modelo salvo em /content/drive/MyDrive/diffusion/saved_models/model_epoch_1.pt
# Época 1/30, Loss Treino: 0.3366, Loss Validação: 0.3241
# [Época 2/30] Batch 1/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 1] Loss: 0.4047 - Restam 89 batches na época
# [Época 2/30] Batch 2/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 2] Loss: 0.6208 - Restam 88 batches na época
# [Época 2/30] Batch 3/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 3] Loss: 0.3334 - Restam 87 batches na época
# [Época 2/30] Batch 4/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 4] Loss: 0.4155 - Restam 86 batches na época
# [Época 2/30] Batch 5/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 5] Loss: 0.4014 - Restam 85 batches na época
# [Época 2/30] Batch 6/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 6] Loss: 0.2054 - Restam 84 batches na época
# [Época 2/30] Batch 7/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch
90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 61] Loss: 0.3652 - Restam 29 batches na época
# [Época 3/30] Batch 62/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 62] Loss: 0.3772 - Restam 28 batches na época
# [Época 3/30] Batch 63/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 63] Loss: 0.2498 - Restam 27 batches na época
# [Época 3/30] Batch 64/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 64] Loss: 0.3232 - Restam 26 batches na época
# [Época 3/30] Batch 65/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 65] Loss: 0.3650 - Restam 25 batches na época
# [Época 3/30] Batch 66/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 66] Loss: 0.4402 - Restam 24 batches na época
# [Época 3/30] Batch 67/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 67] Loss: 0.3062 - Restam 23 batches na época
# [Época 3/30] Batch 68/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 68] Loss: 0.4134 - Restam 22 batches na época
# [Época 3/30] Batch 69/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 69] Loss: 0.4847 - Restam 21 batches na época
# [Época 3/30] Batch 70/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 70] Loss: 0.2544 - Restam 20 batches na época
# [Época 3/30] Batch 71/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 71] Loss: 0.3020 - Restam 19 batches na época
# [Época 3/30] Batch 72/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 72] Loss: 0.4097 - Restam 18 batches na época
# [Época 3/30] Batch 73/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 73] Loss: 0.2046 - Restam 17 batches na época
# [Época 3/30] Batch 74/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 74] Loss: 0.3634 - Restam 16 batches na época
# [Época 3/30] Batch 75/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 75] Loss: 0.3140 - Restam 15 batches na época
# [Época 3/30] Batch 76/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 76] Loss: 0.7135 - Restam 14 batches na época
# [Época 3/30] Batch 77/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 77] Loss: 0.5292 - Restam 13 batches na época
# [Época 3/30] Batch 78/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 78] Loss: 0.3072 - Restam 12 batches na época
# [Época 3/30] Batch 79/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 79] Loss: 0.4619 - Restam 11 batches na época
# [Época 3/30] Batch 80/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 80] Loss: 0.3177 - Restam 10 batches na época
# [Época 3/30] Batch 81/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 81] Loss: 0.3028 - Restam 9 batches na época
# [Época 3/30] Batch 82/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 82] Loss: 0.3455 - Restam 8 batches na época
# [Época 3/30] Batch 83/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 83] Loss: 0.5198 - Restam 7 batches na época
# [Época 3/30] Batch 84/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 84] Loss: 0.6230 - Restam 6 batches na época
# [Época 3/30] Batch 85/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 85] Loss: 0.3464 - Restam 5 batches na época
# [Época 3/30] Batch 86/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 86] Loss: 0.3697 - Restam 4 batches na época
# [Época 3/30] Batch 87/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 87] Loss: 0.1536 - Restam 3 batches na época
# [Época 3/30] Batch 88/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 88] Loss: 0.4206 - Restam 2 batches na época
# [Época 3/30] Batch 89/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
#   [Batch 89] Loss: 0.1571 - Restam 1 batches na época
# [Época 3/30] Batch 90/90 - Forma do batch ajustado: torch.Size([1, 1, 16000])
#   [Batch 90] Loss: 0.3394 - Restam 0 batches na época
# Modelo salvo em /content/drive/MyDrive/diffusion/saved_models/model_epoch_3.pt
# Época 3/30, Loss Treino: 0.3727, Loss Validação: 0.3959
# [Época 4/30] Batch 1/90 - Forma do batch ajustado: torch.Size([4, 1, 16000])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7da186b0f5c8> in <cell line: 47>()
#      73             optimizer.zero_grad()
#      74             loss = model(batch)  # Calcula a perda
# ---> 75             loss.backward()
#      76             xm.optimizer_step(optimizer)  # Atualização de gradientes na TPU
#      77             epoch_train_loss += loss.item()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), f"{save_path}/model_weights.pth")
print("Pesos do modelo salvos como 'model_weights.pth'.")
# Out:
# Pesos do modelo salvos como 'model_weights.pth'.

# %%
save_path = "/content/drive/MyDrive/diffusion/saved_models"  # Diretório para salvar os modelos no Google Drive
model.load_state_dict(torch.load(f"{save_path}/model_epoch_{5}.pt", map_location=device))
# Out:
# <ipython-input-11-48d198278813>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"{save_path}/model_epoch_{5}.pt", map_location=device))
# <All keys matched successfully>

# %%
noise = torch.randn(1, 1, 16000).to(device) # [batch_size, in_channels, length]
sample = model.sample(noise, num_steps=10) # Suggested num_steps 10-100

# %%
if sample.dim() == 3:
    # Se o tensor tem 3 dimensões (batch, canal, comprimento), remova o batch
    generated_audio = sample.squeeze(0)  # Remove a dimensão do batch

# %%
# Salvar o áudio gerado (se bem-sucedido)
if 'generated_audio' in locals():
    import torchaudio
    torchaudio.save(f"{save_path}/generated_audio.wav", generated_audio.cpu(), sample_rate=22050)
    print("Áudio gerado e salvo com sucesso!")
# Out:
# Áudio gerado e salvo com sucesso!

# %%
def sample_audio(model, num_steps=50, initial_noise=None):
    """
    Função para gerar áudio amostrando do modelo de difusão.
    """
    device = next(model.parameters()).device  # Obtém o dispositivo do modelo
    model.eval()  # Coloca o modelo em modo de avaliação

    # Gera ruído inicial se não fornecido
    if initial_noise is None:
        initial_noise = torch.randn(1, 1, 16000).to(device)  # Certifique-se de que está no dispositivo correto

    # Move o ruído inicial explicitamente para o dispositivo do modelo
    initial_noise = initial_noise.to(device)

    # Iteração reversa para geração de áudio
    current_audio = initial_noise
    print(f"Forma do ruído inicial: {current_audio.shape}")

    for step in range(num_steps):
        # Use o método forward do modelo para ajustar o áudio
        with torch.no_grad():
            output = model.diffusion(current_audio)  # Corrigido para usar o método correto

            # Adicione verificação para saída válida
            if output.dim() == 0 or output.shape != current_audio.shape:
                raise ValueError(
                    f"Erro na geração no passo {step + 1}: saída inválida com forma {output.shape}"
                )

            current_audio = output  # Atualiza o áudio gerado
        print(f"Passo {step + 1}/{num_steps}: Forma do áudio gerado: {current_audio.shape}")

    return current_audio

# %%
# Modificar temporariamente o método forward para debugging
def debug_forward(self, x, **kwargs):
    print(f"Forward chamado com entrada: {x.shape}")
    result = super(type(self), self).forward(x, **kwargs)
    if result.dim() == 0 or result.shape != x.shape:
        print(f"Forward saída inválida: {result.shape}")
    return result

# Substituir temporariamente o método forward para inspeção
model.diffusion.forward = debug_forward.__get__(model.diffusion, type(model.diffusion))

# %%
from torch import nn

class VDiffusion(nn.Module):
    def forward(self, x, **kwargs):
        # Exemplo básico de difusão
        print(f"VDiffusion forward: Entrada {x.shape}")
        # Simular uma transformação básica
        return x * 0.9  # Exemplo: Escala de 90%

# %%
#from torch.nn import Module

model.diffusion = VDiffusion()

# %%
# Ruído inicial
initial_noise = torch.randn(1, 1, 16000).to(device)

# Geração de áudio
try:
    generated_audio = sample_audio(model, num_steps=500, initial_noise=initial_noise)
except ValueError as e:
    print(f"Erro durante a geração: {e}")

# Garantir que o tensor seja 2D para salvar corretamente (canal x comprimento)
if generated_audio.dim() == 3:
    # Se o tensor tem 3 dimensões (batch, canal, comprimento), remova o batch
    generated_audio = generated_audio.squeeze(0)  # Remove a dimensão do batch

# Verificar forma do tensor final
print(f"Forma final do áudio gerado: {generated_audio.shape}")

# Certificar que o tensor está no formato correto para salvar
if generated_audio.dim() != 2:
    raise ValueError("O áudio gerado não está no formato correto (canal x comprimento).")

# Salvar o áudio gerado (se bem-sucedido)
if 'generated_audio' in locals():
    import torchaudio
    torchaudio.save(f"{save_path}/generated_audio.wav", generated_audio.cpu(), sample_rate=22050)
    print("Áudio gerado e salvo com sucesso!")
# Out:
# Forma do ruído inicial: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 1/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 2/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 3/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 4/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 5/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 6/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 7/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 8/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 9/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 10/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 11/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 12/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 13/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 14/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 15/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 16/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 17/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 18/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 19/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 20/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 21/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 22/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 23/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 24/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 25/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 26/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 27/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 28/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 29/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 30/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 31/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 32/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 33/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 34/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 35/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 36/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 37/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 38/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 39/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 40/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 41/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 42/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 43/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 44/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 45/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 46/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 47/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 48/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 49/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 50/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 51/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 52/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 53/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 54/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 55/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 56/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 57/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 58/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 59/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 60/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 61/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 62/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 63/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 64/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 65/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 66/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 67/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 68/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 69/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 70/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 71/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 72/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 73/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 74/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 75/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 76/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 77/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 78/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 79/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 80/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 81/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 82/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 83/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 84/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 85/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 86/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 87/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 88/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 89/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 90/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 91/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 92/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 93/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 94/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 95/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 96/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 97/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 98/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 99/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 100/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 101/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 102/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 103/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 104/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 105/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 106/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 107/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 108/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 109/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 110/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 111/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 112/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 113/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 114/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 115/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 116/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 117/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 118/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 119/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 120/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 121/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 122/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 123/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 124/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 125/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 126/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 127/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 128/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 129/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 130/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 131/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 132/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 133/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 134/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 135/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 136/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 137/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 138/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 139/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 140/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 141/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 142/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 143/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 144/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 145/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 146/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 147/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 148/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 149/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 150/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 151/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 152/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 153/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 154/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 155/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 156/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 157/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 158/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 159/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 160/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 161/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 162/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 163/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 164/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 165/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 166/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 167/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 168/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 169/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 170/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 171/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 172/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 173/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 174/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 175/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 176/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 177/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 178/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 179/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 180/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 181/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 182/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 183/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 184/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 185/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 186/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 187/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 188/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 189/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 190/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 191/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 192/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 193/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 194/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 195/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 196/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 197/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 198/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 199/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 200/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 201/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 202/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 203/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 204/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 205/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 206/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 207/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 208/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 209/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 210/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 211/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 212/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 213/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 214/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 215/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 216/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 217/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 218/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 219/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 220/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 221/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 222/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 223/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 224/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 225/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 226/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 227/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 228/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 229/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 230/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 231/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 232/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 233/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 234/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 235/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 236/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 237/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 238/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 239/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 240/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 241/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 242/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 243/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 244/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 245/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 246/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 247/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 248/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 249/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 250/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 251/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 252/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 253/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 254/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 255/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 256/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 257/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 258/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 259/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 260/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 261/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 262/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 263/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 264/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 265/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 266/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 267/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 268/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 269/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 270/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 271/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 272/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 273/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 274/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 275/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 276/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 277/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 278/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 279/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 280/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 281/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 282/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 283/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 284/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 285/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 286/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 287/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 288/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 289/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 290/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 291/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 292/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 293/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 294/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 295/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 296/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 297/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 298/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 299/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 300/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 301/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 302/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 303/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 304/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 305/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 306/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 307/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 308/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 309/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 310/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 311/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 312/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 313/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 314/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 315/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 316/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 317/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 318/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 319/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 320/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 321/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 322/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 323/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 324/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 325/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 326/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 327/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 328/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 329/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 330/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 331/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 332/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 333/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 334/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 335/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 336/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 337/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 338/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 339/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 340/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 341/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 342/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 343/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 344/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 345/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 346/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 347/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 348/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 349/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 350/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 351/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 352/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 353/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 354/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 355/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 356/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 357/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 358/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 359/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 360/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 361/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 362/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 363/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 364/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 365/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 366/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 367/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 368/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 369/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 370/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 371/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 372/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 373/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 374/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 375/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 376/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 377/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 378/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 379/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 380/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 381/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 382/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 383/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 384/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 385/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 386/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 387/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 388/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 389/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 390/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 391/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 392/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 393/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 394/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 395/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 396/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 397/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 398/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 399/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 400/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 401/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 402/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 403/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 404/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 405/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 406/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 407/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 408/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 409/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 410/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 411/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 412/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 413/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 414/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 415/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 416/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 417/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 418/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 419/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 420/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 421/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 422/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 423/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 424/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 425/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 426/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 427/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 428/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 429/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 430/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 431/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 432/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 433/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 434/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 435/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 436/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 437/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 438/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 439/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 440/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 441/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 442/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 443/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 444/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 445/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 446/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 447/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 448/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 449/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 450/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 451/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 452/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 453/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 454/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 455/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 456/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 457/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 458/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 459/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 460/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 461/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 462/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 463/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 464/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 465/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 466/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 467/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 468/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 469/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 470/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 471/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 472/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 473/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 474/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 475/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 476/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 477/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 478/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 479/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 480/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 481/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 482/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 483/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 484/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 485/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 486/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 487/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 488/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 489/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 490/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 491/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 492/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 493/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 494/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 495/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 496/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 497/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 498/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 499/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# VDiffusion forward: Entrada torch.Size([1, 1, 16000])
# Passo 500/500: Forma do áudio gerado: torch.Size([1, 1, 16000])
# Forma final do áudio gerado: torch.Size([1, 16000])
# Áudio gerado e salvo com sucesso!

# %%
output_path = f"{save_path}/generated_audio_raw.wav"
torchaudio.save(output_path, generated_waveform.cpu(), sample_rate)
print(f"Áudio gerado e salvo em: {output_path}")

#generated_waveform = generated_waveform.squeeze(0).cpu()  # Remove batch dimension
generated_waveform = generated_waveform / generated_waveform.abs().max()  # Normaliza entre -1 e 1
output_path = f"{save_path}/generated_audio_norm.wav"
torchaudio.save(output_path, generated_waveform.cpu(), sample_rate)
print(f"Áudio gerado e salvo em: {output_path}")
# Out:
# Áudio gerado e salvo em: /content/drive/MyDrive/diffusion/saved_models/generated_audio_raw.wav
# Áudio gerado e salvo em: /content/drive/MyDrive/diffusion/saved_models/generated_audio_norm.wav
